# %%
# Step 1:
# Summarizing pdf into text

# Step 2:
# Then summarized text with user query is fed into the LLM to generate a concise summary of the content.

# TODO: If the pdf is too long, we use indexing(it will keep the sections as indexed documents in the vector database) to store the summarized text,
# such that we can retrieve relevant sections based on the user query, and pass it to the LLM.

# Indexing :- Convert the pdf text into smaller sections like para by para
# Langchain

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# https://app.eraser.io/workspace/zjUq4ETunws45jthYzRh
